# %%
import pandas as pd 
df=pd.read_csv('train_data.csv')  #read the csv file into pandas frame

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df
# Out:
#       CategoryCode  ItemCode      DateID  DailySales
# 0       category_2    117610   11/6/2021           7
# 1       category_4    836584  11/18/2021          16
# 2       category_1    370195   1/24/2022           6
# 3       category_2    172582  10/30/2021           5
# 4       category_2   1006009  10/30/2021           5
# ...            ...       ...         ...         ...
# 19916   category_2    225259   10/4/2021           4
# 19917   category_2    111436  10/12/2021           1
# 19918   category_2   1098502   10/1/2021           1
# 19919   category_2     20824   10/1/2021           7
# 19920   category_1    371104   10/4/2021           4
#
# [19921 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['CategoryCode', 'ItemCode', 'DateID', 'DailySales'], dtype='object')

# %%
df.describe().round(2)
# Out:
#          ItemCode  DailySales
# count    19921.00    19921.00
# mean    611060.96        7.35
# std     454986.78       14.61
# min       3418.00        1.00
# 25%     117610.00        2.00
# 50%     837943.00        3.00
# 75%    1058713.00        7.00
# max    1105027.00      434.00

# %%
corr_matrix = df.corr().round(2)
corr_matrix
# Out:
#             ItemCode  DailySales
# ItemCode        1.00       -0.13
# DailySales     -0.13        1.00

# %%
#df['wom'] = df['Date'].apply(lambda d: (d.day-1) // 7 + 1)

# %%
import datetime
df['Date'] = pd.to_datetime(df['DateID'])
df['Date'] = df['Date'].dt.strftime('%d.%m.%Y')
df['year'] = pd.DatetimeIndex(df['Date']).year
df['month'] = pd.DatetimeIndex(df['Date']).month
df['day'] = pd.DatetimeIndex(df['Date']).day
df['week'] = pd.DatetimeIndex(df['Date']).week
#df['week'] = pd.DatetimeIndex(df['Date'].isocalendar().week)
df['dayofyear'] = pd.DatetimeIndex(df['Date']).dayofyear
df['weekday'] = pd.DatetimeIndex(df['Date']).weekday
df['quarter'] = pd.DatetimeIndex(df['Date']).quarter
df['is_month_start'] = pd.DatetimeIndex(df['Date']).is_month_start
df['is_month_end'] = pd.DatetimeIndex(df['Date']).is_month_end
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19921 entries, 0 to 19920
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CategoryCode    19921 non-null  object
#  1   ItemCode        19921 non-null  int64
#  2   DateID          19921 non-null  object
#  3   DailySales      19921 non-null  int64
#  4   Date            19921 non-null  object
#  5   year            19921 non-null  int64
#  6   month           19921 non-null  int64
#  7   day             19921 non-null  int64
#  8   week            19921 non-null  int64
#  9   dayofyear       19921 non-null  int64
#  10  weekday         19921 non-null  int64
#  11  quarter         19921 non-null  int64
#  12  is_month_start  19921 non-null  bool
#  13  is_month_end    19921 non-null  bool
# dtypes: bool(2), int64(9), object(3)
# memory usage: 1.9+ MB
# None
# C:\Users\mailt\AppData\Local\Temp/ipykernel_12276/1127780983.py:7: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   df['week'] = pd.DatetimeIndex(df['Date']).week

# %%
df
# Out:
#       CategoryCode  ItemCode      DateID  DailySales        Date  year  month  \
# 0       category_2    117610   11/6/2021           7  06.11.2021  2021      6
# 1       category_4    836584  11/18/2021          16  18.11.2021  2021     11
# 2       category_1    370195   1/24/2022           6  24.01.2022  2022      1
# 3       category_2    172582  10/30/2021           5  30.10.2021  2021     10
# 4       category_2   1006009  10/30/2021           5  30.10.2021  2021     10
# ...            ...       ...         ...         ...         ...   ...    ...
# 19916   category_2    225259   10/4/2021           4  04.10.2021  2021      4
# 19917   category_2    111436  10/12/2021           1  12.10.2021  2021     12
# 19918   category_2   1098502   10/1/2021           1  01.10.2021  2021      1
# 19919   category_2     20824   10/1/2021           7  01.10.2021  2021      1
# 19920   category_1    371104   10/4/2021           4  04.10.2021  2021      4
#
#        day  week  dayofyear  weekday  quarter  is_month_start  is_month_end
# 0       11    23        162        4        2           False         False
# 1       18    46        322        3        4           False         False
# 2       24     4         24        0        1           False         False
# 3       30    43        303        5        4           False         False
# 4       30    43        303        5        4           False         False
# ...    ...   ...        ...      ...      ...             ...           ...
# 19916   10    14        100        5        2           False         False
# 19917   10    49        344        4        4           False         False
# 19918   10     1         10        6        1           False         False
# 19919   10     1         10        6        1           False         False
# 19920   10    14        100        5        2           False         False
#
# [19921 rows x 14 columns]

# %%
df['week'].mask(df['week'] > 38, (df['week']-38)%4, inplace=True)

# %%
df['week'].mask(df['week']==0, 4, inplace=True)

# %%
df['week'].mask(df['week']==5, 1, inplace=True)

# %%
df['week'].mask(df['week']==6, 2, inplace=True)

# %%
df.head(20)
# Out:
#    CategoryCode  ItemCode      DateID  DailySales        Date  year  month  \
# 0    category_2    117610   11/6/2021           7  06.11.2021  2021      6
# 1    category_4    836584  11/18/2021          16  18.11.2021  2021     11
# 2    category_1    370195   1/24/2022           6  24.01.2022  2022      1
# 3    category_2    172582  10/30/2021           5  30.10.2021  2021     10
# 4    category_2   1006009  10/30/2021           5  30.10.2021  2021     10
# 5    category_2    903976    1/6/2022           1  06.01.2022  2022      6
# 6    category_1    145978  10/30/2021           3  30.10.2021  2021     10
# 7    category_1   1061341   1/24/2022           5  24.01.2022  2022      1
# 8    category_1    371239    1/5/2022           1  05.01.2022  2022      5
# 9    category_2    865933    2/8/2022           3  08.02.2022  2022      8
# 10   category_3   1081087    1/4/2022           1  04.01.2022  2022      4
# 11   category_1   1061341   12/7/2021           8  07.12.2021  2021      7
# 12   category_1   1032550  10/30/2021           1  30.10.2021  2021     10
# 13   category_2   1090249  10/23/2021           3  23.10.2021  2021     10
# 14   category_3    169504    1/5/2022         120  05.01.2022  2022      5
# 15   category_2   1067092   11/6/2021           8  06.11.2021  2021      6
# 16   category_1   1054978    2/8/2022           7  08.02.2022  2022      8
# 17   category_1   1050046  10/30/2021           3  30.10.2021  2021     10
# 18   category_1   1044610   12/7/2021           2  07.12.2021  2021      7
# 19   category_2    138742    2/8/2022           9  08.02.2022  2022      8
#
#     day  week  dayofyear  weekday  quarter  is_month_start  is_month_end
# 0    11    23        162        4        2           False         False
# 1    18     4        322        3        4           False         False
# 2    24     4         24        0        1           False         False
# 3    30     1        303        5        4           False         False
# 4    30     1        303        5        4           False         False
# 5     1    22        152        2        2            True         False
# 6    30     1        303        5        4           False         False
# 7    24     4         24        0        1           False         False
# 8     1    17        121        6        2            True         False
# 9     2    31        214        1        3           False         False
# 10    1    13         91        4        2            True         False
# 11   12    28        193        0        3           False         False
# 12   30     1        303        5        4           False         False
# 13   23     4        296        5        4           False         False
# 14    1    17        121        6        2            True         False
# 15   11    23        162        4        2           False         False
# 16    2    31        214        1        3           False         False
# 17   30     1        303        5        4           False         False
# 18   12    28        193        0        3           False         False
# 19    2    31        214        1        3           False         False

# %%
df_new=df[['CategoryCode', 'ItemCode','year','month','week','DailySales']]

# %%
df_new
# Out:
#       CategoryCode  ItemCode  year  month  week  DailySales
# 0       category_2    117610  2021      6    23           7
# 1       category_4    836584  2021     11     4          16
# 2       category_1    370195  2022      1     4           6
# 3       category_2    172582  2021     10     1           5
# 4       category_2   1006009  2021     10     1           5
# ...            ...       ...   ...    ...   ...         ...
# 19916   category_2    225259  2021      4    14           4
# 19917   category_2    111436  2021     12     3           1
# 19918   category_2   1098502  2021      1     1           1
# 19919   category_2     20824  2021      1     1           7
# 19920   category_1    371104  2021      4    14           4
#
# [19921 rows x 6 columns]

# %%
dt=df_new.groupby(['CategoryCode','ItemCode','year','month','week']).agg({'DailySales':['sum']})

# %%
dt
# Out:
#                                       DailySales
#                                              sum
# CategoryCode ItemCode year month week
# category_1   3418     2021 1     1            18
#                                  2            21
#                            2     2            29
#                            3     10           25
#                            4     14           12
# ...                                          ...
# category_4   1082743  2022 8     31           38
#                            9     35           14
#                            10    1             2
#                            11    2            15
#                            12    2            11
#
# [7226 rows x 1 columns]

# %%
dt.head(10)
# Out:
#                                       DailySales
#                                              sum
# CategoryCode ItemCode year month week
# category_1   3418     2021 1     1            18
#                                  2            21
#                            2     2            29
#                            3     10           25
#                            4     14           12
#                                  15           12
#                            5     19           20
#                            6     23           28
#                            7     27            8
#                                  28           11

# %%
dt.columns=['WeeklySales']

# %%
dt
# Out:
#                                        WeeklySales
# CategoryCode ItemCode year month week
# category_1   3418     2021 1     1              18
#                                  2              21
#                            2     2              29
#                            3     10             25
#                            4     14             12
# ...                                            ...
# category_4   1082743  2022 8     31             38
#                            9     35             14
#                            10    1               2
#                            11    2              15
#                            12    2              11
#
# [7226 rows x 1 columns]

# %%
dt=dt.reset_index()

# %%
dt
# Out:
#      CategoryCode  ItemCode  year  month  week  WeeklySales
# 0      category_1      3418  2021      1     1           18
# 1      category_1      3418  2021      1     2           21
# 2      category_1      3418  2021      2     2           29
# 3      category_1      3418  2021      3    10           25
# 4      category_1      3418  2021      4    14           12
# ...           ...       ...   ...    ...   ...          ...
# 7221   category_4   1082743  2022      8    31           38
# 7222   category_4   1082743  2022      9    35           14
# 7223   category_4   1082743  2022     10     1            2
# 7224   category_4   1082743  2022     11     2           15
# 7225   category_4   1082743  2022     12     2           11
#
# [7226 rows x 6 columns]

# %%
dt.head(30)
# Out:
#    CategoryCode  ItemCode  year  month  week  WeeklySales
# 0    category_1      3418  2021      1     1           18
# 1    category_1      3418  2021      1     2           21
# 2    category_1      3418  2021      2     2           29
# 3    category_1      3418  2021      3    10           25
# 4    category_1      3418  2021      4    14           12
# 5    category_1      3418  2021      4    15           12
# 6    category_1      3418  2021      5    19           20
# 7    category_1      3418  2021      6    23           28
# 8    category_1      3418  2021      7    27            8
# 9    category_1      3418  2021      7    28           11
# 10   category_1      3418  2021      8    32           32
# 11   category_1      3418  2021      9    36           19
# 12   category_1      3418  2021     10     1           44
# 13   category_1      3418  2021     10     2           14
# 14   category_1      3418  2021     10     3           48
# 15   category_1      3418  2021     10     4           41
# 16   category_1      3418  2021     11     1           54
# 17   category_1      3418  2021     11     2           12
# 18   category_1      3418  2021     11     3           39
# 19   category_1      3418  2021     11     4           49
# 20   category_1      3418  2021     12     1           75
# 21   category_1      3418  2021     12     2           39
# 22   category_1      3418  2021     12     3           23
# 23   category_1      3418  2021     12     4           73
# 24   category_1      3418  2022      1     1           22
# 25   category_1      3418  2022      1     2           68
# 26   category_1      3418  2022      1     3           89
# 27   category_1      3418  2022      1     4           67
# 28   category_1      3418  2022      2     1           30
# 29   category_1      3418  2022      2     2            3

# %%
test_data = pd.read_csv('test_data.csv')  #read the csv file into pandas frame

# %%
validation_data = pd.read_csv('validation_data.csv')  #read the csv file into pandas frame

# %%
validation_data
# Out:
#     CategoryCode  ItemCode Week  WeeklySales
# 0     category_2   1044502   w1           11
# 1     category_2   1105009   w1           11
# 2     category_2    913561   w4            5
# 3     category_1   1048975   w4           30
# 4     category_1     17287   w2           60
# ..           ...       ...  ...          ...
# 365   category_2    124954   w2           43
# 366   category_2     40759   w1           48
# 367   category_1   1090303   w1           19
# 368   category_2   1090276   w3            6
# 369   category_1      3418   w4           69
#
# [370 rows x 4 columns]

# %%
dt[dt['ItemCode']==174436]
# Out:
#      CategoryCode  ItemCode  year  month  week  WeeklySales
# 3688   category_2    174436  2021      1     1            9
# 3689   category_2    174436  2021      1     2           22
# 3690   category_2    174436  2021      2     2           23
# 3691   category_2    174436  2021      3    10           32
# 3692   category_2    174436  2021      4    14           11
# 3693   category_2    174436  2021      4    15            7
# 3694   category_2    174436  2021      5    19           22
# 3695   category_2    174436  2021      6    23           31
# 3696   category_2    174436  2021      7    27           33
# 3697   category_2    174436  2021      7    28            8
# 3698   category_2    174436  2021      8    32           20
# 3699   category_2    174436  2021      9    36           30
# 3700   category_2    174436  2021     10     1           85
# 3701   category_2    174436  2021     10     2            3
# 3702   category_2    174436  2021     10     3           65
# 3703   category_2    174436  2021     10     4           69
# 3704   category_2    174436  2021     11     1           90
# 3705   category_2    174436  2021     11     2           21
# 3706   category_2    174436  2021     11     3           44
# 3707   category_2    174436  2021     11     4           47
# 3708   category_2    174436  2021     12     1           41
# 3709   category_2    174436  2021     12     2           28
# 3710   category_2    174436  2021     12     3           21
# 3711   category_2    174436  2021     12     4           51
# 3712   category_2    174436  2022      1     1           19
# 3713   category_2    174436  2022      1     2           40
# 3714   category_2    174436  2022      1     3           45
# 3715   category_2    174436  2022      1     4           62
# 3716   category_2    174436  2022      2     1           13
# 3717   category_2    174436  2022      2     2            6
# 3718   category_2    174436  2022      3     9           21
# 3719   category_2    174436  2022      4    13           14
# 3720   category_2    174436  2022      5    17            1
# 3721   category_2    174436  2022      5    18            2
# 3722   category_2    174436  2022      6    22           10
# 3723   category_2    174436  2022      7    26           18
# 3724   category_2    174436  2022      8    31            5
# 3725   category_2    174436  2022      9    35           12
# 3726   category_2    174436  2022     10     1           11
# 3727   category_2    174436  2022     11     2           11
# 3728   category_2    174436  2022     12     2           20

# %%
dt_category1=dt[dt['CategoryCode']=='category_1']

# %%
dt_category1
# Out:
#      CategoryCode  ItemCode  year  month  week  WeeklySales
# 0      category_1      3418  2021      1     1           18
# 1      category_1      3418  2021      1     2           21
# 2      category_1      3418  2021      2     2           29
# 3      category_1      3418  2021      3    10           25
# 4      category_1      3418  2021      4    14           12
# ...           ...       ...   ...    ...   ...          ...
# 2497   category_1   1090303  2022      7    26            5
# 2498   category_1   1090303  2022      8    31            4
# 2499   category_1   1090303  2022      9    35            1
# 2500   category_1   1090303  2022     10     1            6
# 2501   category_1   1090303  2022     12     2            2
#
# [2502 rows x 6 columns]

# %%
dt_category1.plot(kind = 'scatter',
           x = 'week',
           y = 'WeeklySales',
           figsize=(8,6))
plt.savefig('plot4.png')
plt.show()
